# %% [markdown]
# <a href="https://colab.research.google.com/github/arshad-huh/100Days-Python-Practice/blob/main/14_matplotlib_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Using the iris dataset from seaborn, create a scatter plot to show the relationship between sepal_length and sepal_width for each species. Add a legend to indicate species.

# %%
iris = sns.load_dataset('iris')

sns.scatterplot(data= iris, x ='sepal_length', y = 'sepal_width', hue = "species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# 2. Using the tips dataset from seaborn, create a bar plot showing the average total bill for each day of the week, with error bars representing the standard error of the mean.

# %%
tips = sns.load_dataset('tips')

sns.barplot(data=tips, x='day', y='total_bill', errorbar='sd')
plt.ylabel('Average Total Bill')
plt.title('Average Total Bill by Day of the Week')
plt.show()

# %% [markdown]
# 3. Using the penguins dataset from seaborn, create a box plot to compare the flipper length across different species. Display the data points on top of the box plot using a swarm plot.

# %%
peng = sns.load_dataset('penguins')

plt.figure(figsize=(10,6))
sns.boxplot(y='flipper_length_mm', x='species', data=peng, hue='species', fill=False)
sns.swarmplot(y='flipper_length_mm', x='species', data=peng, hue='species')
plt.title('Flipper Length by Species')
plt.show()

# %% [markdown]
# 4. Using the diamonds dataset from seaborn, create a violin plot to show the distribution of diamond prices for different cuts.

# %%
diam = sns.load_dataset('diamonds')

plt.figure(figsize=(10,6))
sns.violinplot(x='cut', y='price', data=diam)
plt.show()

# %% [markdown]
# 5. Using the flights dataset from seaborn, create a heatmap to show the number of passengers for each month and year.

# %%
flights = sns.load_dataset('flights')
flights

flights_pivot = flights.pivot(index='month', columns='year', values='passengers')

plt.figure(figsize=(12, 8))
sns.heatmap(flights_pivot, annot=True, fmt='d')
# fmt='d'-- formats these values as integers.
plt.show()

# %% [markdown]
# 6. Using the titanic dataset from seaborn, create a point plot to show the survival rate across different classes, differentiated by gender.

# %%
titanic = sns.load_dataset('titanic')

sns.pointplot(x='class', y='survived', data=titanic, hue='sex')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Class and Gender')
plt.show()
